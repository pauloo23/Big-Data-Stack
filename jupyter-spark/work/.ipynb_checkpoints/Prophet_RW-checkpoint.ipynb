# %%
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
from pandas.tseries.offsets import BDay
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse
from statsmodels.tsa.stattools import adfuller, kpss
from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

pd.set_option("display.max_rows", None, "display.max_columns", None)

#LoadCSV
df = pd.read_csv(r'C:\Users\asousa\Desktop\Produtech\PPS4\AnáliseDados\dadospps4\Encomendas\combined_csv.csv', sep=";")
#Dias2020
df2020 = pd.read_csv(r'C:\Users\asousa\Desktop\Produtech\PPS4\AnáliseDados\dadospps4\Encomendas\D2020.csv')

#Formatação Dataframe
df = df.drop(columns=['Sold-To Party', 'Name 1', 'Sales Document', 'Purchase order no.', 'Material', 'Description', 'Delivery Date', 'Created By'])

df['Order Quantity'] = df['Order Quantity'].str.replace(",", ".")
df['Order Quantity'] = pd.to_numeric(df['Order Quantity'])

df2020['Dias'] = pd.to_datetime(df2020['Dias'])
df2020 = df2020.sort_values(by='Dias').reset_index(drop=True)

df['Document Date'] = pd.to_datetime(df['Document Date'])

#Groupby Dia
df_gb = df.groupby(df['Document Date'].dt.date).sum().reset_index()

df = pd.DataFrame(df_gb)
df2020 = pd.DataFrame(df2020)

#Dias uteis [df]
isBusinessDay = BDay().is_on_offset
dias_semana = pd.to_datetime(df['Document Date']).map(isBusinessDay)
df["dias_semana"] = dias_semana

#Divisao em dataframes com os dias uteis e fins de semana [df]
df_smn = df[df['dias_semana'] == 1].reset_index(drop=True)
df_fs = df[df['dias_semana'] == 0]

#Dias uteis [df2020]
work_day = pd.to_datetime(df2020['Dias']).map(isBusinessDay)
df2020['work_day'] = work_day

#Divisao em dataframes com os dias uteis e fins de semana [df2020]
df_smn_20 = df2020[df2020['work_day'] == 1].reset_index(drop=True)
df_fs_20 = df2020[df2020['work_day'] == 0]


#Formataçao
df_smn_20.rename(columns={"Dias" : "Document Date"}, inplace=True)
df_smn_20["Document Date"] = df_smn_20["Document Date"].astype("str")

df_test = pd.merge(df_smn, df_smn_20, on="Document Date", how="outer")
df_test["Document Date"]  = pd.to_datetime(df_test["Document Date"])
df_test.sort_values(by='Document Date').reset_index(drop=True)

df_test = df_test.groupby(['Document Date']).apply(lambda x: x[~x['Document Date'].duplicated() | ~x['Order Quantity'].isna()]) 
df = df_test.reset_index(drop=True)
df = df.drop(columns=["dias_semana", "work_day"])
df['Order Quantity'] = df['Order Quantity'].fillna(0)

# %%
def hold(y, ratio=2 / 3, mode="rolling", it=1, window=10, increment=1):
    #ratio = test size
    #window = traingin size
    ALLITR = None
    VAL = None
    NSIZE = len(y)
    if mode == "incremental" or mode == "rolling":
        aux = window + increment * (it - 1)
        aux = min(aux, NSIZE)
        if mode == "rolling":
            iaux = max((aux - window + 1), 1)
        else:
            iaux = 1
        ALLTR = range(iaux, aux)
        end = aux + ratio
        end = min(end, NSIZE)
        iend = aux + 1
        if iend < end:
            TS = range(iend, end)
        else:
            TS = None
    return {"tr": ALLTR, "itr": ALLITR, "val": VAL, "ts": TS}

# %%
def calcIterationsRW(datasetSize, trainingSize, testSize, stepSize): 
    
    return int((datasetSize - (trainingSize + testSize))/ stepSize)

trainingSize = 130
testSize = 6
ratio = testSize
stepSize = 6
#totalLenght = df.shape[0]
mode = "rolling"

iterations = calcIterationsRW(df.shape[0], trainingSize, testSize, stepSize)

#For only positive records
#iterations = calcIterationsRW(len(df['serial'].unique()), trainingSize, testSize, stepSize)

iterations
# Out:
# 21

# %%
df['Document Date'] = pd.to_datetime(df['Document Date'])
#df = df.set_index('Document Date')

#_df = df.resample('D').mean()
#_df = _df.reset_index().dropna()
#_df.columns = ['ds', 'y']

df = df.rename({'Document Date': 'ds', 'Order Quantity' : 'y'}, axis=1)  # new method   
#df_train = train[['Document Date', 'Order Quantity']]
#df_train = df_train.rename({'Document Date': 'ds', 'Order Quantity' : 'y'}, axis=1)  # new method

#df_test = test[['Document Date', 'Order Quantity']]
#df_test = df_test.rename({'Document Date': 'ds', 'Order Quantity' : 'y'}, axis=1)  # new method
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\tools\Anaconda3\envs\PPS4\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\tools\Anaconda3\envs\PPS4\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\tools\Anaconda3\envs\PPS4\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Document Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16116/3234561342.py in <module>
# ----> 1 df['Document Date'] = pd.to_datetime(df['Document Date'])
#       2 #df = df.set_index('Document Date')
#       3
#       4 #_df = df.resample('D').mean()
#       5 #_df = _df.reset_index().dropna()
#
# C:\tools\Anaconda3\envs\PPS4\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# C:\tools\Anaconda3\envs\PPS4\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Document Date'

# %%
from fbprophet import Prophet
from tqdm import trange
from sklearn.metrics import mean_absolute_error

def runarima(data, iterations):
    max_value = data['y'].max()
    min_value = data['y'].min()
    denominator = max_value - min_value
    
    dfFinal = pd.DataFrame(columns = ['MAE', 'NMAE'])
    
    MAEVals = []
    NMAEVals = []
   
    for i in trange(iterations):

            holds = hold(data[['y']], ratio, mode, i+1, trainingSize, stepSize)
            print('holds')
            print("Iteration ", i+1 , "of ", iterations, " TR: ", holds['tr'] , "TS: ", holds['ts'])
            tr = data.iloc[holds['tr']].reset_index(drop=True)
            ts = data.iloc[holds['ts']].reset_index(drop=True)
            
            m = Prophet()
            m.fit(tr)

            p = m.predict(ts)
            
            print(ts)
            print(p)
            
            MAE = mean_absolute_error(ts['y'].values.tolist(), p['yhat'])
            NMAE = (MAE/denominator)*100 #o denominador é calculado com o maximo e minimo global
            
            print("Iteration ", i , "MAE ", MAE, "NMAE of ", NMAE)
            
            MAEVals.append(MAE)
            NMAEVals.append(NMAE)
        
            new = {'MAE': MAE, 'NMAE': NMAE}
            dfFinal = dfFinal.append(new, ignore_index=True)
            dfFinal = pd.DataFrame(dfFinal)
            
    return dfFinal

# %%
dfResults = runarima(df,iterations)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# holds
# Iteration  1 of  21  TR:  range(1, 130) TS:  range(131, 136)
#   5%|▍         | 1/21 [00:05<01:58,  5.93s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-07-02   9805.79
# 1 2020-07-03      0.00
# 2 2020-07-06      0.00
# 3 2020-07-07  12297.51
# 4 2020-07-08  11207.75
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-07-02  13558.288760 -9944.053276  31965.864975  13558.287805
# 1 2020-07-03  13574.754393 -2248.524552  41356.097922  13574.736847
# 2 2020-07-06  13624.151292 -4355.875976  36434.400406  13624.035559
# 3 2020-07-07  13640.616925 -6458.065680  35184.551080  13640.456288
# 4 2020-07-08  13657.082558 -7087.330846  36879.786386  13656.861325
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  13558.295191     -904.741602           -904.741602           -904.741602
# 1  13574.785592     5456.016537           5456.016537           5456.016537
# 2  13624.307750     2983.857186           2983.857186           2983.857186
# 3  13640.829163     1260.705132           1260.705132           1260.705132
# 4  13657.366114     1804.201640           1804.201640           1804.201640
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  -904.741602   -904.741602   -904.741602                   0.0
# 1  5456.016537   5456.016537   5456.016537                   0.0
# 2  2983.857186   2983.857186   2983.857186                   0.0
# 3  1260.705132   1260.705132   1260.705132                   0.0
# 4  1804.201640   1804.201640   1804.201640                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  12653.547157
# 1                         0.0                         0.0  19030.770929
# 2                         0.0                         0.0  16608.008478
# 3                         0.0                         0.0  14901.322057
# 4                         0.0                         0.0  15461.284198
# Iteration  0 MAE  9068.776563854679 NMAE of  9.922643884457576
# holds
# Iteration  2 of  21  TR:  range(7, 136) TS:  range(137, 142)
#  10%|▉         | 2/21 [00:10<01:38,  5.18s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-07-10  14277.50
# 1 2020-07-13  40018.35
# 2 2020-07-14  10957.08
# 3 2020-07-15  22646.59
# 4 2020-07-16  14739.88
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-07-10  14507.290433   161.466530  40307.449076  14507.290103
# 1 2020-07-13  14541.712425 -5559.909158  35292.908651  14541.706983
# 2 2020-07-14  14553.186422 -8020.277642  34843.673342  14553.178124
# 3 2020-07-15  14564.660419 -5541.748769  35148.145760  14564.648969
# 4 2020-07-16  14576.134416 -8983.189942  31763.619577  14576.118949
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  14507.290522     4501.587425           4501.587425           4501.587425
# 1  14541.717948      763.329850            763.329850            763.329850
# 2  14553.194216     -248.345924           -248.345924           -248.345924
# 3  14564.671373     1021.878750           1021.878750           1021.878750
# 4  14576.148674    -3318.808159          -3318.808159          -3318.808159
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  4501.587425   4501.587425   4501.587425                   0.0
# 1   763.329850    763.329850    763.329850                   0.0
# 2  -248.345924   -248.345924   -248.345924                   0.0
# 3  1021.878750   1021.878750   1021.878750                   0.0
# 4 -3318.808159  -3318.808159  -3318.808159                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  19008.877857
# 1                         0.0                         0.0  15305.042275
# 2                         0.0                         0.0  14304.840498
# 3                         0.0                         0.0  15586.539169
# 4                         0.0                         0.0  11257.326258
# Iteration  1 MAE  8667.010130746814 NMAE of  9.483049280666435
# holds
# Iteration  3 of  21  TR:  range(13, 142) TS:  range(143, 148)
#  14%|█▍        | 3/21 [00:14<01:19,  4.44s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-07-20   7150.44
# 1 2020-07-21   8744.88
# 2 2020-07-22  40194.90
# 3 2020-07-23  15517.90
# 4 2020-07-24  22680.61
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-07-20  16394.552434 -2770.497818  39159.824408  16394.552034
# 1 2020-07-21  16422.809891 -5498.185225  36091.437843  16422.809255
# 2 2020-07-22  16451.067348 -3895.852731  38402.199411  16451.066496
# 3 2020-07-23  16479.324805 -8308.839972  34071.036101  16479.323575
# 4 2020-07-24  16507.582262 -1299.008915  41349.594751  16507.580706
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  16394.552814     1436.100234           1436.100234           1436.100234
# 1  16422.810512    -1550.856729          -1550.856729          -1550.856729
# 2  16451.068241      753.439421            753.439421            753.439421
# 3  16479.325970    -3064.077997          -3064.077997          -3064.077997
# 4  16507.583710     4458.429491           4458.429491           4458.429491
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  1436.100234   1436.100234   1436.100234                   0.0
# 1 -1550.856729  -1550.856729  -1550.856729                   0.0
# 2   753.439421    753.439421    753.439421                   0.0
# 3 -3064.077997  -3064.077997  -3064.077997                   0.0
# 4  4458.429491   4458.429491   4458.429491                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  17830.652669
# 1                         0.0                         0.0  14871.953162
# 2                         0.0                         0.0  17204.506769
# 3                         0.0                         0.0  13415.246807
# 4                         0.0                         0.0  20966.011753
# Iteration  2 MAE  8722.986100306283 NMAE of  9.54429564704397
# holds
# Iteration  4 of  21  TR:  range(19, 148) TS:  range(149, 154)
#  19%|█▉        | 4/21 [00:19<01:21,  4.77s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds        y
# 0 2020-07-28  9450.83
# 1 2020-07-29  8360.39
# 2 2020-07-30  7589.11
# 3 2020-07-31  5151.89
# 4 2020-08-03     0.00
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-07-28  14985.289985 -7354.634498  36014.999046  14985.289559
# 1 2020-07-29  14998.377678 -4225.364265  37476.004930  14998.377006
# 2 2020-07-30  15011.465371 -9540.302803  32540.803872  15011.464463
# 3 2020-07-31  15024.553063  -532.712214  40656.188831  15024.551840
# 4 2020-08-03  15063.816142 -7193.873081  37027.813168  15063.813595
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  14985.290528    -1354.639995          -1354.639995          -1354.639995
# 1  14998.378521     1919.784843           1919.784843           1919.784843
# 2  15011.466506    -2191.795986          -2191.795986          -2191.795986
# 3  15024.554613     4402.980706           4402.980706           4402.980706
# 4  15063.819036     1196.303251           1196.303251           1196.303251
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0 -1354.639995  -1354.639995  -1354.639995                   0.0
# 1  1919.784843   1919.784843   1919.784843                   0.0
# 2 -2191.795986  -2191.795986  -2191.795986                   0.0
# 3  4402.980706   4402.980706   4402.980706                   0.0
# 4  1196.303251   1196.303251   1196.303251                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  13630.649990
# 1                         0.0                         0.0  16918.162520
# 2                         0.0                         0.0  12819.669385
# 3                         0.0                         0.0  19427.533770
# 4                         0.0                         0.0  16260.119393
# Iteration  3 MAE  9700.783011524323 NMAE of  10.614156666667022
# holds
# Iteration  5 of  21  TR:  range(25, 154) TS:  range(155, 160)
#  24%|██▍       | 5/21 [00:25<01:24,  5.31s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-08-05   6058.92
# 1 2020-08-06  21579.47
# 2 2020-08-07  20501.67
# 3 2020-08-10  17517.51
# 4 2020-08-11      0.00
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-08-05  13195.688418 -7001.065212  34144.411160  13195.686487
# 1 2020-08-06  13208.465455 -8190.992492  33380.990363  13208.451142
# 2 2020-08-07  13221.242492  -213.677943  40371.625496  13221.211236
# 3 2020-08-10  13259.573602 -5375.446400  37138.401320  13259.470868
# 4 2020-08-11  13272.350638 -8185.155720  34303.961538  13272.220122
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  13195.690176     1334.106161           1334.106161           1334.106161
# 1  13208.475402     -639.474130           -639.474130           -639.474130
# 2  13221.269816     6477.219693           6477.219693           6477.219693
# 3  13259.662299     3007.503254           3007.503254           3007.503254
# 4  13272.457271      686.307709            686.307709            686.307709
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  1334.106161   1334.106161   1334.106161                   0.0
# 1  -639.474130   -639.474130   -639.474130                   0.0
# 2  6477.219693   6477.219693   6477.219693                   0.0
# 3  3007.503254   3007.503254   3007.503254                   0.0
# 4   686.307709    686.307709    686.307709                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  14529.794580
# 1                         0.0                         0.0  12568.991325
# 2                         0.0                         0.0  19698.462185
# 3                         0.0                         0.0  16267.076855
# 4                         0.0                         0.0  13958.658347
# Iteration  4 MAE  6698.73051247391 NMAE of  7.329447019144106
# holds
# Iteration  6 of  21  TR:  range(31, 160) TS:  range(161, 166)
#  29%|██▊       | 6/21 [00:31<01:21,  5.40s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds        y
# 0 2020-08-13   632.95
# 1 2020-08-14  2211.09
# 2 2020-08-17  6128.66
# 3 2020-08-18  7878.42
# 4 2020-08-19  1039.33
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-08-13  13265.166636 -8519.990424  32740.563180  13265.165803
# 1 2020-08-14  13272.962258  -599.551977  39541.375619  13272.959207
# 2 2020-08-17  13296.349127 -5227.839309  37616.492590  13296.335583
# 3 2020-08-18  13304.144750 -7377.290708  32215.370866  13304.126456
# 4 2020-08-19  13311.940373 -6987.008809  34487.159755  13311.916775
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  13265.167565    -1213.410932          -1213.410932          -1213.410932
# 1  13272.965664     5899.492623           5899.492623           5899.492623
# 2  13296.366590     2585.472981           2585.472981           2585.472981
# 3  13304.167421     -448.443894           -448.443894           -448.443894
# 4  13311.970330      525.092927            525.092927            525.092927
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0 -1213.410932  -1213.410932  -1213.410932                   0.0
# 1  5899.492623   5899.492623   5899.492623                   0.0
# 2  2585.472981   2585.472981   2585.472981                   0.0
# 3  -448.443894   -448.443894   -448.443894                   0.0
# 4   525.092927    525.092927    525.092927                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  12051.755703
# 1                         0.0                         0.0  19172.454882
# 2                         0.0                         0.0  15881.822109
# 3                         0.0                         0.0  12855.700856
# 4                         0.0                         0.0  13837.033300
# Iteration  5 MAE  11181.663369935422 NMAE of  12.234468770349004
# holds
# Iteration  7 of  21  TR:  range(37, 166) TS:  range(167, 172)
#  33%|███▎      | 7/21 [00:36<01:12,  5.20s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-08-21   5094.27
# 1 2020-08-24  18536.38
# 2 2020-08-25   6321.48
# 3 2020-08-26   5827.80
# 4 2020-08-27  13347.06
#           ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0 2020-08-21  23820.990285  -2544.301110  37852.654013  23820.990078
# 1 2020-08-24  23772.079220  -7059.138169  32600.499863  23772.075196
# 2 2020-08-25  23755.775531  -8442.046862  31942.507379  23755.769973
# 3 2020-08-26  23739.471842 -10277.252273  30729.165065  23739.464804
# 4 2020-08-27  23723.168154  -9677.719772  30281.060240  23723.158960
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  23820.990367    -6954.132617          -6954.132617          -6954.132617
# 1  23772.081723   -10095.921623         -10095.921623         -10095.921623
# 2  23755.779664   -13554.438376         -13554.438376         -13554.438376
# 3  23739.477326   -13488.536636         -13488.536636         -13488.536636
# 4  23723.175952   -13722.368872         -13722.368872         -13722.368872
#
#          weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  -6954.132617  -6954.132617  -6954.132617                   0.0
# 1 -10095.921623 -10095.921623 -10095.921623                   0.0
# 2 -13554.438376 -13554.438376 -13554.438376                   0.0
# 3 -13488.536636 -13488.536636 -13488.536636                   0.0
# 4 -13722.368872 -13722.368872 -13722.368872                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  16866.857668
# 1                         0.0                         0.0  13676.157596
# 2                         0.0                         0.0  10201.337155
# 3                         0.0                         0.0  10250.935207
# 4                         0.0                         0.0  10000.799282
# Iteration  6 MAE  5656.412630222566 NMAE of  6.188990080199966
# holds
# Iteration  8 of  21  TR:  range(43, 172) TS:  range(173, 178)
#  38%|███▊      | 8/21 [00:42<01:13,  5.65s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds        y
# 0 2020-08-31  9259.05
# 1 2020-09-01  5324.43
# 2 2020-09-02     0.00
# 3 2020-09-03  6117.45
# 4 2020-09-04  1621.26
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-08-31  12298.022176 -3501.306006  32657.439524  12298.021141
# 1 2020-09-01  12296.685512 -8736.016740  29357.605746  12296.683852
# 2 2020-09-02  12295.348849 -6731.648907  30181.239180  12295.346339
# 3 2020-09-03  12294.012185 -7573.661885  31532.363219  12294.008688
# 4 2020-09-04  12292.675521 -3998.641953  32502.829273  12292.671051
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  12298.023100     3217.404432           3217.404432           3217.404432
# 1  12296.687092     -686.934418           -686.934418           -686.934418
# 2  12295.351098     -925.328057           -925.328057           -925.328057
# 3  12294.015406     -862.364532           -862.364532           -862.364532
# 4  12292.679630     2630.951356           2630.951356           2630.951356
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  3217.404432   3217.404432   3217.404432                   0.0
# 1  -686.934418   -686.934418   -686.934418                   0.0
# 2  -925.328057   -925.328057   -925.328057                   0.0
# 3  -862.364532   -862.364532   -862.364532                   0.0
# 4  2630.951356   2630.951356   2630.951356                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  15515.426608
# 1                         0.0                         0.0  11609.751094
# 2                         0.0                         0.0  11370.020791
# 3                         0.0                         0.0  11431.647653
# 4                         0.0                         0.0  14923.626877
# Iteration  7 MAE  8505.656604685413 NMAE of  9.306503572727161
# holds
# Iteration  9 of  21  TR:  range(49, 178) TS:  range(179, 184)
#  43%|████▎     | 9/21 [00:49<01:12,  6.08s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-09-08      0.00
# 1 2020-09-09   8046.64
# 2 2020-09-10  46162.59
# 3 2020-09-11  38999.50
# 4 2020-09-14  40598.12
#           ds        trend    yhat_lower    yhat_upper  trend_lower  \
# 0 2020-09-08  9796.250133 -10040.062347  27117.746274  9796.248082
# 1 2020-09-09  9787.231438  -6498.225019  29705.153157  9787.227721
# 2 2020-09-10  9778.212743  -5429.986324  29962.199787  9778.207268
# 3 2020-09-11  9769.194048  -4116.907756  32106.384840  9769.186550
# 4 2020-09-14  9742.137963  -2102.242114  34420.272768  9742.122668
#
#    trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  9796.252385     -469.683557           -469.683557           -469.683557
# 1  9787.235358      975.850456            975.850456            975.850456
# 2  9778.218278     1356.809586           1356.809586           1356.809586
# 3  9769.201674     3736.477895           3736.477895           3736.477895
# 4  9742.152190     5247.209625           5247.209625           5247.209625
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  -469.683557   -469.683557   -469.683557                   0.0
# 1   975.850456    975.850456    975.850456                   0.0
# 2  1356.809586   1356.809586   1356.809586                   0.0
# 3  3736.477895   3736.477895   3736.477895                   0.0
# 4  5247.209625   5247.209625   5247.209625                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0   9326.566576
# 1                         0.0                         0.0  10763.081894
# 2                         0.0                         0.0  11135.022329
# 3                         0.0                         0.0  13505.671943
# 4                         0.0                         0.0  14989.347589
# Iteration  8 MAE  19634.635321962218 NMAE of  21.483327186331273
# holds
# Iteration  10 of  21  TR:  range(55, 184) TS:  range(185, 190)
#  48%|████▊     | 10/21 [00:55<01:05,  5.92s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-09-16   7740.37
# 1 2020-09-17  25846.99
# 2 2020-09-18  19684.34
# 3 2020-09-21   8091.61
# 4 2020-09-22  10000.41
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-09-16  15110.366264 -7741.658932  33287.797189  15110.366225
# 1 2020-09-17  15125.537976 -4058.224796  33576.239305  15125.537496
# 2 2020-09-18  15140.709688  -956.674126  37886.359908  15140.708750
# 3 2020-09-21  15186.224824   -63.894379  37203.466581  15186.221349
# 4 2020-09-22  15201.396536 -8281.845543  29135.001159  15201.392275
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  15110.366375    -2102.453551          -2102.453551          -2102.453551
# 1  15125.538608        9.468880              9.468880              9.468880
# 2  15140.710880     1709.745377           1709.745377           1709.745377
# 3  15186.228352     2943.059113           2943.059113           2943.059113
# 4  15201.401048    -3320.160021          -3320.160021          -3320.160021
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0 -2102.453551  -2102.453551  -2102.453551                   0.0
# 1     9.468880      9.468880      9.468880                   0.0
# 2  1709.745377   1709.745377   1709.745377                   0.0
# 3  2943.059113   2943.059113   2943.059113                   0.0
# 4 -3320.160021  -3320.160021  -3320.160021                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  13007.912713
# 1                         0.0                         0.0  15135.006856
# 2                         0.0                         0.0  16850.455065
# 3                         0.0                         0.0  18129.283937
# 4                         0.0                         0.0  11881.236515
# Iteration  9 MAE  6146.382248621972 NMAE of  6.725092607740282
# holds
# Iteration  11 of  21  TR:  range(61, 190) TS:  range(191, 196)
#  52%|█████▏    | 11/21 [00:58<00:52,  5.24s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-09-24  11264.62
# 1 2020-09-25  23238.94
# 2 2020-09-28   7975.94
# 3 2020-09-29   9353.69
# 4 2020-09-30  16429.04
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-09-24  13211.003722 -5522.789376  33301.031299  13211.003211
# 1 2020-09-25  13207.249023 -2342.122491  34409.600165  13207.246730
# 2 2020-09-28  13195.984926 -1787.614923  34225.328805  13195.973900
# 3 2020-09-29  13192.230227 -7742.140713  29702.154100  13192.214187
# 4 2020-09-30  13188.475527 -6954.698675  28972.143094  13188.454769
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  13211.003889      502.475765            502.475765            502.475765
# 1  13207.250586     2710.139887           2710.139887           2710.139887
# 2  13195.995453     2889.735211           2889.735211           2889.735211
# 3  13192.244413    -2609.439206          -2609.439206          -2609.439206
# 4  13188.493498    -2123.188649          -2123.188649          -2123.188649
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0   502.475765    502.475765    502.475765                   0.0
# 1  2710.139887   2710.139887   2710.139887                   0.0
# 2  2889.735211   2889.735211   2889.735211                   0.0
# 3 -2609.439206  -2609.439206  -2609.439206                   0.0
# 4 -2123.188649  -2123.188649  -2123.188649                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  13713.479487
# 1                         0.0                         0.0  15917.388910
# 2                         0.0                         0.0  16085.720137
# 3                         0.0                         0.0  10582.791020
# 4                         0.0                         0.0  11065.286878
# Iteration  10 MAE  4894.608971238136 NMAE of  5.355459078001996
# holds
# Iteration  12 of  21  TR:  range(67, 196) TS:  range(197, 202)
#  57%|█████▋    | 12/21 [01:02<00:42,  4.69s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-10-02  11010.20
# 1 2020-10-05      0.00
# 2 2020-10-06  23250.35
# 3 2020-10-07  37429.27
# 4 2020-10-08   4558.74
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-10-02  14878.010631 -1759.967840  36407.829708  14878.009127
# 1 2020-10-05  14901.862847  -482.980806  36338.846627  14901.839952
# 2 2020-10-06  14909.813585 -5636.680109  29915.637952  14909.776621
# 3 2020-10-07  14917.764324 -6018.563827  30982.108021  14917.717238
# 4 2020-10-08  14925.715062 -3384.812367  32873.493735  14925.660283
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  14878.012467     2786.870846           2786.870846           2786.870846
# 1  14901.887485     2457.625061           2457.625061           2457.625061
# 2  14909.848647    -3797.338015          -3797.338015          -3797.338015
# 3  14917.810340    -2384.990685          -2384.990685          -2384.990685
# 4  14925.771983      101.443149            101.443149            101.443149
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  2786.870846   2786.870846   2786.870846                   0.0
# 1  2457.625061   2457.625061   2457.625061                   0.0
# 2 -3797.338015  -3797.338015  -3797.338015                   0.0
# 3 -2384.990685  -2384.990685  -2384.990685                   0.0
# 4   101.443149    101.443149    101.443149                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  17664.881477
# 1                         0.0                         0.0  17359.487908
# 2                         0.0                         0.0  11112.475570
# 3                         0.0                         0.0  12532.773639
# 4                         0.0                         0.0  15027.158211
# Iteration  11 MAE  14303.391677190692 NMAE of  15.650122257764771
# holds
# Iteration  13 of  21  TR:  range(73, 202) TS:  range(203, 208)
#  62%|██████▏   | 13/21 [01:05<00:32,  4.10s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-10-12  15894.53
# 1 2020-10-13  10384.92
# 2 2020-10-14  14951.67
# 3 2020-10-15  15096.58
# 4 2020-10-16   7337.90
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-10-12  13915.327237   -50.873552  36058.097962  13915.325699
# 1 2020-10-13  13936.692224 -6057.718690  32787.471272  13936.689704
# 2 2020-10-14  13958.057211 -5305.314126  30852.382535  13958.053157
# 3 2020-10-15  13979.422198 -3007.005610  33758.495574  13979.416291
# 4 2020-10-16  14000.787184   629.597891  38488.279079  14000.779585
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  13915.328645     4057.073127           4057.073127           4057.073127
# 1  13936.694657     -692.147503           -692.147503           -692.147503
# 2  13958.061070     -801.137418           -801.137418           -801.137418
# 3  13979.427655     1472.874389           1472.874389           1472.874389
# 4  14000.794629     5254.423081           5254.423081           5254.423081
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  4057.073127   4057.073127   4057.073127                   0.0
# 1  -692.147503   -692.147503   -692.147503                   0.0
# 2  -801.137418   -801.137418   -801.137418                   0.0
# 3  1472.874389   1472.874389   1472.874389                   0.0
# 4  5254.423081   5254.423081   5254.423081                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  17972.400364
# 1                         0.0                         0.0  13244.544720
# 2                         0.0                         0.0  13156.919793
# 3                         0.0                         0.0  15452.296587
# 4                         0.0                         0.0  19255.210266
# Iteration  12 MAE  3801.054428893645 NMAE of  4.158941310085661
# holds
# Iteration  14 of  21  TR:  range(79, 208) TS:  range(209, 214)
#  67%|██████▋   | 14/21 [01:08<00:26,  3.85s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-10-20  27189.52
# 1 2020-10-21   3186.87
# 2 2020-10-22  12013.83
# 3 2020-10-23   9312.22
# 4 2020-10-26   7594.31
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-10-20  13255.495766 -5812.551372  30184.288763  13255.490214
# 1 2020-10-21  13254.921537 -5622.222727  30800.478299  13254.912348
# 2 2020-10-22  13254.347308 -4894.077909  31627.398452  13254.333979
# 3 2020-10-23  13253.773079  -466.216893  35327.758250  13253.755561
# 4 2020-10-26  13252.050393   -24.093906  34262.048654  13252.015670
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  13255.499716    -1722.109506          -1722.109506          -1722.109506
# 1  13254.927543    -1692.227478          -1692.227478          -1692.227478
# 2  13254.355487      806.180057            806.180057            806.180057
# 3  13253.785128     3923.885385           3923.885385           3923.885385
# 4  13252.074763     3633.327999           3633.327999           3633.327999
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0 -1722.109506  -1722.109506  -1722.109506                   0.0
# 1 -1692.227478  -1692.227478  -1692.227478                   0.0
# 2   806.180057    806.180057    806.180057                   0.0
# 3  3923.885385   3923.885385   3923.885385                   0.0
# 4  3633.327999   3633.327999   3633.327999                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  11533.386260
# 1                         0.0                         0.0  11562.694059
# 2                         0.0                         0.0  14060.527365
# 3                         0.0                         0.0  17177.658465
# 4                         0.0                         0.0  16885.378391
# Iteration  13 MAE  8647.032404034142 NMAE of  9.461190558445738
# holds
# Iteration  15 of  21  TR:  range(85, 214) TS:  range(215, 220)
#  71%|███████▏  | 15/21 [01:12<00:22,  3.81s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-10-28  11425.11
# 1 2020-10-29  23494.74
# 2 2020-10-30  20351.55
# 3 2020-11-02  21792.83
# 4 2020-11-03   8006.11
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-10-28  12186.421263 -5565.691525  29804.383006  12186.410677
# 1 2020-10-29  12188.255795 -3156.090068  31298.851120  12188.207383
# 2 2020-10-30  12190.090326  -834.981207  33828.924269  12189.992001
# 3 2020-11-02  12195.593921  -964.528633  33368.363124  12195.297737
# 4 2020-11-03  12197.428452 -6022.112605  29059.732840  12197.035561
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  12186.429267     -731.182232           -731.182232           -731.182232
# 1  12188.300195     1996.691340           1996.691340           1996.691340
# 2  12190.179494     4071.809425           4071.809425           4071.809425
# 3  12195.933539     4353.712438           4353.712438           4353.712438
# 4  12197.872274    -1827.234794          -1827.234794          -1827.234794
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  -731.182232   -731.182232   -731.182232                   0.0
# 1  1996.691340   1996.691340   1996.691340                   0.0
# 2  4071.809425   4071.809425   4071.809425                   0.0
# 3  4353.712438   4353.712438   4353.712438                   0.0
# 4 -1827.234794  -1827.234794  -1827.234794                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  11455.239031
# 1                         0.0                         0.0  14184.947135
# 2                         0.0                         0.0  16261.899751
# 3                         0.0                         0.0  16549.306359
# 4                         0.0                         0.0  10370.193658
# Iteration  14 MAE  4207.435888747447 NMAE of  4.603585466767949
# holds
# Iteration  16 of  21  TR:  range(91, 220) TS:  range(221, 226)
#  76%|███████▌  | 16/21 [01:15<00:19,  3.82s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-11-05   8101.56
# 1 2020-11-06   5510.06
# 2 2020-11-09  19799.15
# 3 2020-11-10      0.00
# 4 2020-11-11  24723.84
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-11-05  11124.859941 -2917.949418  32263.257415  11124.859926
# 1 2020-11-06  11115.274579 -2230.670532  33412.084115  11115.274513
# 2 2020-11-09  11086.518494  -237.714599  34130.410288  11086.518192
# 3 2020-11-10  11076.933132 -8871.963944  26959.883873  11076.932723
# 4 2020-11-11  11067.347771 -5910.619989  27771.890431  11067.347257
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  11124.859957     2821.835185           2821.835185           2821.835185
# 1  11115.274637     4996.302105           4996.302105           4996.302105
# 2  11086.518796     5368.573561           5368.573561           5368.573561
# 3  11076.933521    -1473.391025          -1473.391025          -1473.391025
# 4  11067.348271     -564.904738           -564.904738           -564.904738
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  2821.835185   2821.835185   2821.835185                   0.0
# 1  4996.302105   4996.302105   4996.302105                   0.0
# 2  5368.573561   5368.573561   5368.573561                   0.0
# 3 -1473.391025  -1473.391025  -1473.391025                   0.0
# 4  -564.904738   -564.904738   -564.904738                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  13946.695126
# 1                         0.0                         0.0  16111.576684
# 2                         0.0                         0.0  16455.092055
# 3                         0.0                         0.0   9603.542108
# 4                         0.0                         0.0  10502.443033
# Iteration  15 MAE  8723.12976597053 NMAE of  9.544452839495975
# holds
# Iteration  17 of  21  TR:  range(97, 226) TS:  range(227, 232)
#  81%|████████  | 17/21 [01:20<00:16,  4.03s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-11-13   4753.10
# 1 2020-11-16  31417.38
# 2 2020-11-17   3527.02
# 3 2020-11-18  18956.28
# 4 2020-11-19  42068.37
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-11-13  12362.874698 -3799.075168  32491.163447  12362.874691
# 1 2020-11-16  12325.289901 -2102.519987  33404.502779  12325.289765
# 2 2020-11-17  12312.761636 -7891.507049  26202.661581  12312.761427
# 3 2020-11-18  12300.233370 -8188.271402  29264.539432  12300.233093
# 4 2020-11-19  12287.705105 -4999.469043  30422.065911  12287.704718
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  12362.874703     2438.117551           2438.117551           2438.117551
# 1  12325.290043     3985.570101           3985.570101           3985.570101
# 2  12312.761865    -3026.799628          -3026.799628          -3026.799628
# 3  12300.233697    -1899.701697          -1899.701697          -1899.701697
# 4  12287.705535     1369.356828           1369.356828           1369.356828
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  2438.117551   2438.117551   2438.117551                   0.0
# 1  3985.570101   3985.570101   3985.570101                   0.0
# 2 -3026.799628  -3026.799628  -3026.799628                   0.0
# 3 -1899.701697  -1899.701697  -1899.701697                   0.0
# 4  1369.356828   1369.356828   1369.356828                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  14800.992249
# 1                         0.0                         0.0  16310.860002
# 2                         0.0                         0.0   9285.962008
# 3                         0.0                         0.0  10400.531673
# 4                         0.0                         0.0  13657.061933
# Iteration  16 MAE  13576.082129759332 NMAE of  14.85433314750138
# holds
# Iteration  18 of  21  TR:  range(103, 232) TS:  range(233, 238)
#  86%|████████▌ | 18/21 [01:24<00:12,  4.08s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-11-23  13596.45
# 1 2020-11-24   9778.60
# 2 2020-11-25   9090.28
# 3 2020-11-26  17205.88
# 4 2020-11-27  30709.11
#           ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0 2020-11-23  23909.587137  -2371.021670  33247.682835  23909.586318
# 1 2020-11-24  23883.049667 -11384.683896  25426.547718  23883.048221
# 2 2020-11-25  23856.512197  -7848.835416  26534.325427  23856.510021
# 3 2020-11-26  23829.974728  -3486.811612  31546.428407  23829.971773
# 4 2020-11-27  23803.437258  -4774.913334  31421.103788  23803.433206
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  23909.587949    -8239.582050          -8239.582050          -8239.582050
# 1  23883.051148   -15981.904196         -15981.904196         -15981.904196
# 2  23856.514432   -14275.438412         -14275.438412         -14275.438412
# 3  23829.977817   -10523.658818         -10523.658818         -10523.658818
# 4  23803.441353   -10167.993541         -10167.993541         -10167.993541
#
#          weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  -8239.582050  -8239.582050  -8239.582050                   0.0
# 1 -15981.904196 -15981.904196 -15981.904196                   0.0
# 2 -14275.438412 -14275.438412 -14275.438412                   0.0
# 3 -10523.658818 -10523.658818 -10523.658818                   0.0
# 4 -10167.993541 -10167.993541 -10167.993541                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  15670.005087
# 1                         0.0                         0.0   7901.145471
# 2                         0.0                         0.0   9581.073785
# 3                         0.0                         0.0  13306.315910
# 4                         0.0                         0.0  13635.443717
# Iteration  17 MAE  5083.006755079209 NMAE of  5.561595385861519
# holds
# Iteration  19 of  21  TR:  range(109, 238) TS:  range(239, 244)
#  90%|█████████ | 19/21 [01:29<00:08,  4.29s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-12-01      0.00
# 1 2020-12-02  19587.51
# 2 2020-12-03   3981.05
# 3 2020-12-04      0.00
# 4 2020-12-07      0.00
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-12-01  13351.585741 -3973.972942  25774.479321  13351.471967
# 1 2020-12-02  13358.113511 -3527.766279  27150.874223  13357.926271
# 2 2020-12-03  13364.641281  2382.134975  31905.867865  13364.346598
# 3 2020-12-04  13371.169050  1178.205448  32248.474798  13370.751699
# 4 2020-12-07  13390.752360  -337.743353  31298.045560  13389.944106
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  13351.741512    -2720.569259          -2720.569259          -2720.569259
# 1  13358.332136    -1051.132206          -1051.132206          -1051.132206
# 2  13364.990019     2594.594563           2594.594563           2594.594563
# 3  13371.641692     3563.561762           3563.561762           3563.561762
# 4  13391.590119     2875.479198           2875.479198           2875.479198
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0 -2720.569259  -2720.569259  -2720.569259                   0.0
# 1 -1051.132206  -1051.132206  -1051.132206                   0.0
# 2  2594.594563   2594.594563   2594.594563                   0.0
# 3  3563.561762   3563.561762   3563.561762                   0.0
# 4  2875.479198   2875.479198   2875.479198                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  10631.016482
# 1                         0.0                         0.0  12306.981305
# 2                         0.0                         0.0  15959.235843
# 3                         0.0                         0.0  16934.730812
# 4                         0.0                         0.0  16266.231558
# Iteration  18 MAE  12618.138678061892 NMAE of  13.806194882575207
# holds
# Iteration  20 of  21  TR:  range(115, 244) TS:  range(245, 250)
#  95%|█████████▌| 20/21 [01:32<00:03,  3.84s/it]INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds         y
# 0 2020-12-09      0.00
# 1 2020-12-10   4496.23
# 2 2020-12-11  63495.23
# 3 2020-12-14   8332.37
# 4 2020-12-15   9780.32
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-12-09  11009.032191 -4223.271655  25650.695108  11009.032073
# 1 2020-12-10  10992.438788 -2050.622043  29651.505352  10992.438393
# 2 2020-12-11  10975.845385 -2381.017145  29116.362848  10975.844626
# 3 2020-12-14  10926.065175 -1551.480778  29805.360457  10926.063069
# 4 2020-12-15  10909.471772 -7081.896723  24900.372921  10909.469071
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  11009.032191     -318.822165           -318.822165           -318.822165
# 1  10992.438991     2748.041915           2748.041915           2748.041915
# 2  10975.845873     2666.412971           2666.412971           2666.412971
# 3  10926.067047     3653.478214           3653.478214           3653.478214
# 4  10909.474227    -2392.644247          -2392.644247          -2392.644247
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0  -318.822165   -318.822165   -318.822165                   0.0
# 1  2748.041915   2748.041915   2748.041915                   0.0
# 2  2666.412971   2666.412971   2666.412971                   0.0
# 3  3653.478214   3653.478214   3653.478214                   0.0
# 4 -2392.644247  -2392.644247  -2392.644247                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  10690.210025
# 1                         0.0                         0.0  13740.480702
# 2                         0.0                         0.0  13642.258355
# 3                         0.0                         0.0  14579.543390
# 4                         0.0                         0.0   8516.827525
# Iteration  19 MAE  15459.619647393924 NMAE of  16.915214447079816
# holds
# Iteration  21 of  21  TR:  range(121, 250) TS:  range(251, 256)
# 100%|██████████| 21/21 [01:35<00:00,  4.54s/it]
#           ds         y
# 0 2020-12-17  11125.33
# 1 2020-12-18  27461.87
# 2 2020-12-21   7933.43
# 3 2020-12-22  19542.20
# 4 2020-12-23   7312.26
#           ds         trend   yhat_lower    yhat_upper   trend_lower  \
# 0 2020-12-17  12342.990196 -4115.800719  30076.254499  12342.990088
# 1 2020-12-18  12321.026512 -1252.722307  32412.232163  12321.025994
# 2 2020-12-21  12255.135461 -2573.799142  30893.360709  12255.132019
# 3 2020-12-22  12233.171777 -8353.966244  24069.892409  12233.166953
# 4 2020-12-23  12211.208094 -6058.544395  25479.137127  12211.201666
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  12342.990324       93.348717             93.348717             93.348717
# 1  12321.027141     3401.724407           3401.724407           3401.724407
# 2  12255.138967     1749.345750           1749.345750           1749.345750
# 3  12233.176655    -4448.176094          -4448.176094          -4448.176094
# 4  12211.214306    -2268.215827          -2268.215827          -2268.215827
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0    93.348717     93.348717     93.348717                   0.0
# 1  3401.724407   3401.724407   3401.724407                   0.0
# 2  1749.345750   1749.345750   1749.345750                   0.0
# 3 -4448.176094  -4448.176094  -4448.176094                   0.0
# 4 -2268.215827  -2268.215827  -2268.215827                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  12436.338913
# 1                         0.0                         0.0  15722.750920
# 2                         0.0                         0.0  14004.481211
# 3                         0.0                         0.0   7784.995683
# 4                         0.0                         0.0   9942.992267
# Iteration  20 MAE  6701.823157800022 NMAE of  7.332830851352991

# %%
mae_mean = dfResults['MAE'].mean()
nmae_mean = dfResults['NMAE'].mean()
print(mae_mean)
print(nmae_mean)
# Out:
# 9142.779047547741
# 10.003614044774277
